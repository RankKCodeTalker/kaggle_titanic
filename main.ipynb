# %% [markdown]
# # Kaggle比赛之泰坦尼克号幸存者预测
# ## 1 数据预处理
# 首先导入必要的库。

# %%
import pandas as pd

# %% [markdown]
# 读取原始训练集和测试集。

# %%
train_data = pd.read_csv('data/train.csv')
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test_data = pd.read_csv('data/test.csv')
test_data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# （1）记录训练集和测试集的数量。
#
# （2）分割训练集的特征和标签。
#
# （3）合并训练集的特征和测试集构成新的DataFrame。

# %%
num_train = train_data.shape[0]
num_test = test_data.shape[0]
num_train, num_test
# Out:
# (891, 418)

# %%
columns = train_data.columns.values
new_columns = columns[columns != 'Survived']
train_features = train_data.loc[:, new_columns]
train_features
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
train_labels = train_data.loc[:, ['Survived']]
train_labels
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]

# %%
all_features = pd.concat([train_features, test_data])
all_features
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 413         1305       3                                 Spector, Mr. Woolf
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %% [markdown]
# （1）先分析数据并删除无用数据。
#
# （2）连续值（即数值）的缺失值使用平均值填充。
#
# 这里可以先标准化然后用0值来填充，也是一样的效果。
#
# （3）离散值转换成one-hot表示。
#
# get_dummy函数，绝绝子。

# %%
# 对取值进行计数
column = 'Cabin'
all_features.loc[:, column].value_counts(), all_features.loc[:, column].value_counts().value_counts()
# Out:
# (Cabin
#  C23 C25 C27        6
#  G6                 5
#  B57 B59 B63 B66    5
#  C22 C26            4
#  F33                4
#                    ..
#  A14                1
#  E63                1
#  E12                1
#  E38                1
#  C105               1
#  Name: count, Length: 186, dtype: int64,
#  count
#  1    107
#  2     63
#  4      7
#  3      6
#  5      2
#  6      1
#  Name: count, dtype: int64)

# %%
# 判断某一列是否是另一列的子分类
def a_can_infer_b(df: pd.DataFrame, a: str, b: str) -> bool:
    assert a in df.columns, f'{a}不是df的列！'
    assert b in df.columns, f'{b}不是df的列！'
    d = {}
    for i, a_unit, b_unit in zip(range(len(df)), df.loc[:, a], df.loc[:, b]):
        if a_unit not in d:
            d[a_unit] = b_unit
        elif d[a_unit] == b_unit:
            pass
        else:
            return False
    return True

a_can_infer_b(all_features, 'Fare', 'Ticket')
# Out:
# False

# %%
# 删除无用的列
drop_columns = ['PassengerId', 'Name']
columns = all_features.columns.values
for c in drop_columns:
    columns = columns[columns != c]
all_features = all_features.loc[:, columns]
all_features
# Out:
#      Pclass     Sex   Age  SibSp  Parch              Ticket      Fare Cabin  \
# 0         3    male  22.0      1      0           A/5 21171    7.2500   NaN
# 1         1  female  38.0      1      0            PC 17599   71.2833   C85
# 2         3  female  26.0      0      0    STON/O2. 3101282    7.9250   NaN
# 3         1  female  35.0      1      0              113803   53.1000  C123
# 4         3    male  35.0      0      0              373450    8.0500   NaN
# ..      ...     ...   ...    ...    ...                 ...       ...   ...
# 413       3    male   NaN      0      0           A.5. 3236    8.0500   NaN
# 414       1  female  39.0      0      0            PC 17758  108.9000  C105
# 415       3    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN
# 416       3    male   NaN      0      0              359309    8.0500   NaN
# 417       3    male   NaN      1      1                2668   22.3583   NaN
#
#     Embarked
# 0          S
# 1          C
# ...

# %%
all_features.dtypes
# Out:
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
# 若无法获得测试数据，则可根据训练数据计算均值和标准差
numeric_features = all_features.dtypes[all_features.dtypes != 'object'].index
all_features[numeric_features] = all_features[numeric_features].apply(lambda x: (x - x.mean()) / (x.std()))
# 在标准化数据之后，所有均值消失，因此我们可以将缺失值设置为0
all_features[numeric_features] = all_features[numeric_features].fillna(0)
all_features
# Out:
#        Pclass     Sex       Age     SibSp     Parch              Ticket  \
# 0    0.841595    male -0.546789  0.481104 -0.444829           A/5 21171
# 1   -1.545507  female  0.563282  0.481104 -0.444829            PC 17599
# 2    0.841595  female -0.269271 -0.478904 -0.444829    STON/O2. 3101282
# 3   -1.545507  female  0.355144  0.481104 -0.444829              113803
# 4    0.841595    male  0.355144 -0.478904 -0.444829              373450
# ..        ...     ...       ...       ...       ...                 ...
# 413  0.841595    male  0.000000 -0.478904 -0.444829           A.5. 3236
# 414 -1.545507  female  0.632662 -0.478904 -0.444829            PC 17758
# 415  0.841595    male  0.597972 -0.478904 -0.444829  SOTON/O.Q. 3101262
# 416  0.841595    male  0.000000 -0.478904 -0.444829              359309
# 417  0.841595    male  0.000000  0.481104  0.710492                2668
#
#          Fare Cabin Embarked
# 0   -0.503210   NaN        S
# 1    0.733941   C85        C
# ...

# %%
all_features = pd.get_dummies(all_features, dummy_na=True)
all_features
# Out:
#        Pclass       Age     SibSp     Parch      Fare  Sex_female  Sex_male  \
# 0    0.841595 -0.546789  0.481104 -0.444829 -0.503210       False      True
# 1   -1.545507  0.563282  0.481104 -0.444829  0.733941        True     False
# 2    0.841595 -0.269271 -0.478904 -0.444829 -0.490169        True     False
# 3   -1.545507  0.355144  0.481104 -0.444829  0.382632        True     False
# 4    0.841595  0.355144 -0.478904 -0.444829 -0.487754       False      True
# ..        ...       ...       ...       ...       ...         ...       ...
# 413  0.841595  0.000000 -0.478904 -0.444829 -0.487754       False      True
# 414 -1.545507  0.632662 -0.478904 -0.444829  1.460712        True     False
# 415  0.841595  0.597972 -0.478904 -0.444829 -0.503210       False      True
# 416  0.841595  0.000000 -0.478904 -0.444829 -0.487754       False      True
# 417  0.841595  0.000000  0.481104  0.710492 -0.211311       False      True
#
# ...

# %% [markdown]
# ## 2 模型和训练函数的定义

# %%
from model import ModelForSimpleClassification

model = ModelForSimpleClassification()

# %% [markdown]
# ## 3 验证选择训练参数

# %% [markdown]
# ## 4 训练模型

# %% [markdown]
# ## 5 在测试集上预测
